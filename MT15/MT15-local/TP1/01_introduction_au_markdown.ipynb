# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Markdown
#
# Nous allons ici regarder quelques utilisations en markdown.
#
# Vous pouvez double-cliquer sur un texte pour voir le code mardown utilisé. Puis faire Crrl + Entrée pour valider à nouveau la cellule.

# %% [markdown]
# ## Insertion de liens
#
# Un lien utile :
# [Markdown Cells](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html) in Jupyter Notebook

# %% [markdown]
# ## Insetion de titre
# ### sous titre
# #### sous sous titre
# ##### sous sous sous titre

# %% [markdown]
# ## Format de texte
#
# je suis en _italique_
# je suis en __gras__
# je suis en ___italique gras___

# %% [markdown]
# ## Couleur de texte
#
# je suis <font color='red'>rouge</font>
# et moi je suis <font color='green'>vert</font>

# %% [markdown]
# ## Listes
# liste1:
#    * __liste1.1__
#    * liste1.2
#        * _liste1.2.1_
#            * liste 1.2.1.1
#        * liste1.2.2

# %% [markdown]
# ## Insertion de séparateur
#
# ***

# %% [markdown]
# ## Insertion d'équations mathématiques
# le notebook supporte LateX:
# $e^{i\pi} + 1 = 0$

# %% [markdown]
# $$e^x=\sum_{k=0}^\infty \dfrac{1}{k!}x^k$$

# %% [markdown]
# \\( P(A \mid B) = \frac{P(B \mid A) \, P(A)}{P(B)} \\)

# %% [markdown]
# ## Insertion d'image
#
# <img src=https://mybinder.org/static/images/logo_square.png />
# <img src="/content/drive/MyDrive/MT15/TP1/data/logo_square.png"/>

# %% [markdown]
# ## Redirection
# [Retour au titre](#Markdown)

# %% [markdown]
# # Application

# %% [markdown]
# Reproduisez en Markdown le contenu suivant :
#
# <img src ="/content/drive/MyDrive/MT15/TP1/Application1-tp1.PNG">

# %% [markdown]
# # Application
#
# ## Mybinder
#
# Jupyter est une **application web** utilisée pour programmer dans plus de
# <font color='green'>40</font> langages, dont ***R***, ***Python***, ***Julia***.
#
# *C'est un projet libre dont l'objectif est de développer des logiciels libres, des formats
# ouverts et des services pour l'informatique interactive.*
#
# * Source ([https://fr.wikipedia.org/wiki/Jupyter](#https://fr.wikipedia.org/wiki/Jupyter))
#
# <img src="../data/logo_square.png">
